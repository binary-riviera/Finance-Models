# %%
import pandas as pd
import pandas_datareader.data as web
import datetime as dt
# Out:
# C:\Users\Daniel\anaconda3\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %% [markdown]
# We need a function that returns stock trades given an optional ticker, a date, and a buy or sell attribute.

# %%
def get_insider_trades(ticker=None, date=None, action='buy'):
    url = 'http://www.openinsider.com/screener?s=&o=&pl=&ph=&ll=&lh=&fd=-1&fdr={month}%2F{day}%2F{year}+-+{month}%2F{day}%2F{year}&td=0&tdr=&fdlyl=&fdlyh=&daysago=&xp=1&vl=&vh=&ocl=&och=&sic1=-1&sicl=100&sich=9999&grp=0&nfl=&nfh=&nil=&nih=&nol=&noh=&v2l=&v2h=&oc2l=&oc2h=&sortcol=0&cnt=100&page=1'
    if ticker:
        pass
    else:
        # we can just get all trades
        url = url.format(month=date.month,day=date.day,year=date.year)
        return pd.read_html(url)[11]

# %%
get_insider_trades(date=dt.date(2010, 7, 12))
# Out:
#       X          Filing Date  Trade Date Ticker  \
# 0     M  2010-07-12 19:11:04  2010-07-08   ATEA
# 1     M  2010-07-12 19:04:00  2010-07-08    SPB
# 2     M  2010-07-12 19:03:30  2010-07-08   AGYS
# 3     M  2010-07-12 19:00:20  2010-07-08   AGYS
# 4   NaN  2010-07-12 18:40:34  2010-06-22   VVTV
# 5     M  2010-07-12 17:59:02  2010-07-08   ADPT
# 6     M  2010-07-12 17:56:58  2010-07-08    SLI
# 7   NaN  2010-07-12 17:35:19  2010-07-09   SKPI
# 8   NaN  2010-07-12 17:33:50  2010-07-09   SKPI
# 9     M  2010-07-12 17:22:34  2010-05-05   ISRL
# 10  NaN  2010-07-12 17:20:35  2010-07-12   AUBN
# 11  NaN  2010-07-12 17:17:39  2010-07-08   DGSE
# 12  NaN  2010-07-12 17:16:38  2010-07-08    PCX
# 13  NaN  2010-07-12 16:47:04  2010-07-08   DEST
# 14  NaN  2010-07-12 16:28:48  2010-07-09   LBMH
# 15  NaN  2010-07-12 16:17:20  2010-07-08    SIX
# 16  NaN  2010-07-12 16:16:35  2010-07-08   WHRT
# 17  NaN  2010-07-12 16:07:55  2010-07-09    DXR
# ...
